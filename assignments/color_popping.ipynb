# %% [markdown]
# # Color popping

# %% [markdown]
# **Assignment**
# 1. Load the `lorikeet.jpg` image.
# 2. Segment the lorikeet (foreground object of interest) by creating a binary mask.
# 3. Remove color from the background, i.e. make the background grayscale.
#
# <figure class="image">
#   <img src="../figures/color_popping-expected_outputs.png" alt=""/>
#   <figcaption>
#     Expected outputs.<br>
#   </figcaption>
# </figure>

# %%
import sys

import numpy as np
import matplotlib.pyplot as plt
import skimage

if '..' not in sys.path:
    sys.path.append('..')
from tests import test_color_popping

# %%
plt.rcParams['figure.constrained_layout.use'] = True
np.set_printoptions(threshold=20, edgeitems=10, linewidth=140, precision=3, suppress=True)

# %%
rgb = skimage.io.imread('../data/lorikeet.jpg')
rgb.shape, rgb.dtype, rgb.min(), rgb.max()

# %%
plt.imshow(rgb);

# %% [markdown]
# ## Task 1: Segment the lorikeet and create foreground (1) vs background (0) mask

# %% [markdown]
# - Use whatever image segmentation method you want.
# - Cropping the bird manually is not allowed, it must be at least semi-automatic approach.
# - Save the result into a 2D boolean `numpy.ndarray` of the shape (image_height, image_width) under the variable name `mask`.

# %%
########################################
# TODO: implement

raise NotImplementedError

########################################

# %%
test_color_popping.TestMask.eval(img=mask)

# %% [markdown]
# ## Task 2: color-pop the lorikeet

# %% [markdown]
# - Set the background pixels to grayscale.
# - Save the result into a `numpy.ndarray` with variable name `cpop`.

# %%
########################################
# TODO: implement

raise NotImplementedError

########################################

# %%
fig, axes = plt.subplots(1, 3, figsize=plt.figaspect(0.33))
axes[0].imshow(rgb);
axes[1].imshow(mask);
axes[2].imshow(cpop);

# %%
test_color_popping.TestColorPop.eval(img=cpop)
